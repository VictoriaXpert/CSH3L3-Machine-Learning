# %% [markdown]
# ## Tugas 3 - Reinforcement Learning ##
# ### Q-Learning ###
# ##### Febry Ghaisani 1301154576 IF3902 #####
#
# Analisis coming soon...

# %%
import pandas as pd
import numpy as np
import random

# %%
datas1 = np.genfromtxt('DataTugasML3.txt', delimiter='\t',dtype=int)
datas2 = np.zeros((10,10,2))

k = 0
for i in range(10):
    for j in range(10):
        c = datas1[i,j]
        d = np.array([k,c])
        datas2[i,j] = d
        k += 1
# print(datas2)

Q = np.zeros((4,100))
# Q[Q == 0] = -100

# %%
def get_coor_by_action(random,x,y):
    if random == 0:
        x -= 1
        if x<0:
            x += 1
    elif random == 1:
        y += 1
        if y>9:
            y -= 1
    elif random == 2:
        x += 1
        if x>9:
            x -= 1
    elif random == 3:
        y -= 1
        if y<0:
            y += 1
    return x,y

# %%
# Exploration

alpha = 0.1
gamma = 0.9

for j in range(600):
    x = 9
    y = 0
    s = 90
    
#     reward = 0
#     arah = []

    while (x != 0 & y != 9):
        # random action, N=0 S=2 W=3 E=1
        pol = np.random.choice(4, 1)
        x,y = get_coor_by_action(pol,x,y)
    
        # update table Q
        maks = np.amax(Q, axis=0)
        Q[pol,s] = (Q[pol,s] + (alpha*(datas2[x,y][1]+(gamma*maks[int(datas2[x,y][0])]) - Q[pol,s])))
        
        # next state
        s = int(datas2[x,y][0])
        
#         arah.append(pol)
#         reward += datas2[x,y][1]
#     print('reward tiap episode ke : ',j,reward)
print(np.array(Q))
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -9.99492471e-01 -2.99606994e+00
#   -4.99272211e+00 -9.99303801e-01 -2.99847741e+00 -2.98608481e+00
#   -4.98478374e+00 -4.98309304e+00 -9.96956747e-01  9.92930350e+01
#   -2.89900174e+00 -3.59308417e+00 -2.94109427e+00  2.20488881e+00
#    1.49103254e+01  2.24061604e+01  3.95840547e+01  5.16606906e+01
#    6.81860829e+01  8.35879988e+01 -5.60866738e+00 -4.25121922e+00
#    3.30159764e+00  1.06671288e+01  1.55853899e+01  2.27044927e+01
#    3.45398141e+01  4.65277131e+01  5.86590548e+01  6.96930239e+01
#   -4.36021833e+00 -1.13976466e+00  5.70584623e+00  1.04288604e+01
#    1.79744054e+01  2.18594518e+01  3.07066988e+01  4.15991406e+01
#    4.89421265e+01  5.81378182e+01 -6.80751078e-01  4.58052585e+00
#    9.03938069e+00  1.37882800e+01  1.86996821e+01  2.25137376e+01
#    2.73304176e+01  3.22309836e+01  4.04594508e+01  4.78631903e+01
#   -3.32183530e+00  1.47244045e+00  3.72597018e+00  1.00870800e+01
#    1.22813519e+01  1.52266994e+01  2.31428407e+01  2.79632042e+01
#    3.39149713e+01  3.85854451e+01 -5.13228470e+00 -7.61334554e-01
#    2.93270206e+00  5.82010034e+00  9.61598886e+00  1.13018559e+01
#    1.64696442e+01  2.25691843e+01  2.92615621e+01  3.13800881e+01
#   -6.84228392e+00 -2.95528431e+00 -2.53264155e+00  2.05336121e+00
#    7.29317296e+00  5.69805376e+00  9.42445381e+00  1.57307972e+01
#    2.37728892e+01  2.34660563e+01 -4.07932536e+00 -2.20227508e+00
#   -1.08376285e+00  1.50876044e-01  4.99695779e+00  2.53788287e+00
#    7.02633823e+00  1.35691308e+01  1.70276238e+01  1.96586315e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -3
#    2.38625662e+01  2.39640249e+01 -4.20097205e+00 -2.24214155e+00
#   -1.17520445e+00  3.15932229e-02  5.05878673e+00  2.30498051e+00
#    6.74685353e+00  1.35709621e+01  1.70185194e+01  1.93932599e+01
#   -8.83548198e+00 -5.10507244e+00 -2.12076988e+00 -2.22255144e+00
#   -1.15006781e-02 -4.27234294e-01  3.44128940e+00  9.62182394e+00
#    1.26125755e+01  1.53209280e+01 -8.79753427e+00 -5.06586051e+00
#   -2.23433068e+00 -2.18654578e+00 -1.54480380e-02 -6.37290819e-01
#    3.35810445e+00  9.41780220e+00  1.28342496e+01  1.53021167e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -2.89355198e+00 -2.89138724e+00
#   -3.50742624e+00 -3.14374272e+00 -4.34019761e-01  7.81769616e+00
#    2.04260759e+01  3.46263880e+01  4.61859461e+01  6.61676694e+01
#   -5.60830202e+00 -5.60817364e+00 -3.78945127e+00  2.50604739e+00
#    7.96232947e+00  1.34812649e+01  1.93108893e+01  3.35116787e+01
#    4.54125276e+01  5.79980171e+01 -4.97159010e+00 -4.73390339e+00
#   -2.44563190e+00  5.09187906e+00  9.78808941e+00  1.75447087e+01
#    2.17213058e+01  2.99693892e+01  4.11895249e+01  4.87336568e+01
#   -1.51756972e+00 -5.20435405e-01  4.56207980e+00  8.82000750e+00
#    1.36598587e+01  1.80866690e+01  2.27001369e+01  2.65385448e+01
#    3.19606826e+01  3.99669665e+01 -3.25327828e+00 -3.23885256e+00
#    1.48247412e+00  3.54805078e+00  9.99322849e+00  1.21772777e+01
#    1.49817382e+01  2.27995606e+01  2.77255961e+01  3.37595612e+01
#   -5.20800179e+00 -5.22103466e+00 -9.87260831e-01  2.81720547e+00
#    5.72376550e+00  9.51461656e+00  1.12187086e+01  1.60553121e+01
#    2.23787355e+01  2.90482467e+01 -6.85412229e+00 -6.85437141e+00
#   -3.07222369e+00 -2.51694495e+00  1.87621134e+00  7.24421526e+00
#    5.40855475e+00  9.01639203e+00  1.56474771e+01  2.39190882e+01
#   -4.15676498e+00 -4.26478071e+00 -2.23159175e+00 -1.22240115e+00
#   -7.15337173e-03  5.01017152e+00  2.60811107e+00  6.76377096e+00
#    1.37456366e+01  1.69046342e+01 -8.78695451e+00 -8.86070085e+00
#   -5.11679129e+00 -2.13136736e+00 -2.33040242e+00 -2.40744348e-02
#   -5.35037803e-01  3.23771136e+00  9.58326408e+00  1.28166752e+01]]

# %%
# Exploitation

st = 90
xt = 9
yt = 0
rew = 0
state = []

while (st != 9):
    # get max a', Q(s',a')
    makst = np.amax(Q, axis=0)
    pola, st = np.where(Q == makst[st])
    if (pola.size > 1):
        pol = pola[0]
    else:
        pol = pola
        
    xt,yt = get_coor_by_action(pol,xt,yt)
    # next state
    st = int(datas2[xt,yt][0])
    
    state.append(st)
    rew += datas2[xt,yt][1]
    
print(rew)
print(state)
# Out:
# 61.0
# [80, 81, 82, 83, 84, 74, 64, 54, 44, 45, 46, 47, 37, 38, 28, 29, 19, 9]
